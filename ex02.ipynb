# %% [markdown]
# <a href="https://colab.research.google.com/github/KELLYSILVAARAUJO/ESTRUTURAS-DE-DADOS-II/blob/main/ex02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercício 01: Crie um programa que leia 10 números inteiros e armazene-os em um array.

vetor = [] #criando um vetor para armazenar os números
soma = 0

for i in range(10): #criando um for para gerar um loop de 10 números inseridos
    numero = int(input(f"Digite o {i + 1}º número: "))
    vetor.append(numero)
    soma += numero

media = soma / 10

print("\nNúmeros digitados:") #mostrando os números escolhidos
for numero in vetor:
    print(numero, end=" ")

print(f"\nSoma: {soma}") #mostrando as soma dos números inseridos
print(f"Média: {media:.2f}")6
4
8
# Out:
# Digite o 1º número: 12
# Digite o 2º número: 25
# Digite o 3º número: 36
# Digite o 4º número: 25
# Digite o 5º número: 32
# Digite o 6º número: 32
# Digite o 7º número: 21
# Digite o 8º número: 12
# Digite o 9º número: 8
# Digite o 10º número: 5
#
# Números digitados:
# 12 25 36 25 32 32 21 12 8 5
# Soma: 208
# Média: 20.80

# %%
#Exercício 02: Leia 10 números inteiros utilizando um array.

vetor = [] #criando um vetor para armazenar os números

for i in range(10): #criando um for para gerar um loop de 10 números inseridos
    numero = int(input(f"Digite o {i + 1}º número: "))
    vetor.append(numero)

maior = vetor[0]
menor = vetor[0]

for numero in vetor: #um for para mostrar o maior e o menor número
    if numero > maior:
        maior = numero

    if numero < menor:
        menor = numero

print(f"\nMaior valor inserido: {maior}")
print("Posições do maior:", end=" ")

for i in range(10):
    if vetor[i] == maior:
        print(i, end=" ")

print(f"\nMenor valor inserido: {menor}")
print("Posições do menor:", end=" ")

for i in range(10):
    if vetor[i] == menor:
        print(i, end=" ")

print()
# Out:
# Digite o 1º número: 25
# Digite o 2º número: 21
# Digite o 3º número: 14
# Digite o 4º número: 45
# Digite o 5º número: 85
# Digite o 6º número: 6
# Digite o 7º número: 8
# Digite o 8º número: 4
# Digite o 9º número: 4
# Digite o 10º número: 5
#
# Maior valor inserido: 85
# Posições do maior: 4
# Menor valor inserido: 4
# Posições do menor: 7 8
