# %% [markdown]
# <a href="https://colab.research.google.com/github/KELLYSILVAARAUJO/ESTRUTURAS-DE-DADOS-II/blob/main/ex03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercício 01: Crie um programa que leia 10 números inteiros e armazene-os em um array.

vetor = [] #criando um vetor para armazenar os números
soma = 0

for i in range(10): #criando um for para gerar um loop de 10 números inseridos
    numero = int(input(f"Digite o {i + 1}º número: "))
    vetor.append(numero)
    soma += numero

media = soma / 10

print("\nNúmeros digitados:") #mostrando os números escolhidos
for numero in vetor:
    print(numero, end=" ")

print(f"\nSoma: {soma}") #mostrando as soma dos números inseridos
print(f"Média: {media:.2f}")6
4
8
# Out:
# Digite o 1º número: 12
# Digite o 2º número: 25
# Digite o 3º número: 36
# Digite o 4º número: 25
# Digite o 5º número: 32
# Digite o 6º número: 32
# Digite o 7º número: 21
# Digite o 8º número: 12
# Digite o 9º número: 8
# Digite o 10º número: 5
#
# Números digitados:
# 12 25 36 25 32 32 21 12 8 5
# Soma: 208
# Média: 20.80

# %%
#Exercício 03: Leia 20 números inteiros e armazene-os em um array.

vetor = []

for i in range(20): #criando um for para gerar um loop de 10 números inseridos
    numero = int(input(f"Digite o {i + 1}º número: "))
    vetor.append(numero)

quantidade = 0
soma = 0

print("\nNúmeros pares inseridos:")

for numero in vetor:
    if numero % 2 == 0:
        print(numero, end=" ")
        quantidade += 1
        soma += numero

print(f"\n\nQuantidade de números pares: {quantidade}")
print(f"Soma dos números pares: {soma}")
# Out:
# Digite o 1º número: 5
# Digite o 2º número: 5
# Digite o 3º número: 5
# Digite o 4º número: 5
# Digite o 5º número: 4
# Digite o 6º número: 6
# Digite o 7º número: 8
# Digite o 8º número: 9
# Digite o 9º número: 200
# Digite o 10º número:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_721/94746617.py in <cell line: 0>()
#       4
#       5 for i in range(20): #criando um for para gerar um loop de 10 números inseridos
# ----> 6     numero = int(input(f"Digite o {i + 1}º número: "))
#       7     vetor.append(numero)
#       8
#
# ValueError: invalid literal for int() with base 10: ''
